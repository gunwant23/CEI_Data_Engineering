-- %% [markdown]
-- # Superstore Data Analysis

-- %% [markdown]
-- ## 1. Data Exploration

-- %%
select * from superstore
limit 5;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Row ID</th><th>Order ID</th><th>Order Date</th><th>Ship Date</th><th>Ship Mode</th><th>Customer ID</th><th>Customer Name</th><th>Segment</th><th>Country</th><th>City</th><th>State</th><th>Postal Code</th><th>Region</th><th>Product ID</th><th>Category</th><th>Sub-Category</th><th>Product Name</th><th>Sales</th><th>Quantity</th><th>Discount</th><th>Profit</th></tr></thead><tbody><tr><td>1</td><td>CA-2016-152156</td><td>2016-11-08</td><td>2016-11-11</td><td>Second Class</td><td>CG-12520</td><td>Claire Gute</td><td>Consumer</td><td>United States</td><td>Henderson</td><td>Kentucky</td><td>42420</td><td>South</td><td>FUR-BO-10001798</td><td>Furniture</td><td>Bookcases</td><td>Bush Somerset Collection Bookcase</td><td>261.96</td><td>2</td><td>0.0</td><td>41.9136</td></tr><tr><td>2</td><td>CA-2016-152156</td><td>2016-11-08</td><td>2016-11-11</td><td>Second Class</td><td>CG-12520</td><td>Claire Gute</td><td>Consumer</td><td>United States</td><td>Henderson</td><td>Kentucky</td><td>42420</td><td>South</td><td>FUR-CH-10000454</td><td>Furniture</td><td>Chairs</td><td>Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back</td><td>731.94</td><td>3</td><td>0.0</td><td>219.582</td></tr><tr><td>3</td><td>CA-2016-138688</td><td>2016-06-12</td><td>2016-06-16</td><td>Second Class</td><td>DV-13045</td><td>Darrin Van Huff</td><td>Corporate</td><td>United States</td><td>Los Angeles</td><td>California</td><td>90036</td><td>West</td><td>OFF-LA-10000240</td><td>Office Supplies</td><td>Labels</td><td>Self-Adhesive Address Labels for Typewriters by Universal</td><td>14.62</td><td>2</td><td>0.0</td><td>6.8714</td></tr><tr><td>4</td><td>US-2015-108966</td><td>2015-10-11</td><td>2015-10-18</td><td>Standard Class</td><td>SO-20335</td><td>Sean O'Donnell</td><td>Consumer</td><td>United States</td><td>Fort Lauderdale</td><td>Florida</td><td>33311</td><td>South</td><td>FUR-TA-10000577</td><td>Furniture</td><td>Tables</td><td>Bretford CR4500 Series Slim Rectangular Table</td><td>957.5775</td><td>5</td><td>0.45</td><td>-383.031</td></tr><tr><td>5</td><td>US-2015-108966</td><td>2015-10-11</td><td>2015-10-18</td><td>Standard Class</td><td>SO-20335</td><td>Sean O'Donnell</td><td>Consumer</td><td>United States</td><td>Fort Lauderdale</td><td>Florida</td><td>33311</td><td>South</td><td>OFF-ST-10000760</td><td>Office Supplies</td><td>Storage</td><td>Eldon Fold 'N Roll Cart System</td><td>22.368</td><td>2</td><td>0.2</td><td>2.5164</td></tr></tbody></table></div>

-- %%
SELECT COUNT(*) AS total_rows,COUNT(*) AS total_columns
FROM superstore
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_rows</th><th>total_columns</th></tr></thead><tbody><tr><td>9994</td><td>9994</td></tr></tbody></table></div>

-- %%
SELECT 
    COUNT(DISTINCT `Row ID`) AS row_cnt,
    COUNT(DISTINCT `Order ID`) AS ord_cnt,
    COUNT(*) AS total_cnt 
FROM superstore;
--So We can conclude that Row ID is unique and can be used for primary key 
-- First, make Row ID column NOT NULL
ALTER TABLE superstore ALTER COLUMN `Row ID` SET NOT NULL;

-- Then add the primary key constraint
--ALTER TABLE superstore ADD PRIMARY KEY (`Row ID`)

-- %%
show create table superstore 
-- used to retrieve the script for creation of table in db
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>createtab_stmt</th></tr></thead><tbody><tr><td>CREATE TABLE workspace.default.superstore (
--   `Row ID` BIGINT NOT NULL,
--   `Order ID` STRING COLLATE UTF8_BINARY,
--   `Order Date` DATE,
--   `Ship Date` DATE,
--   `Ship Mode` STRING COLLATE UTF8_BINARY,
--   `Customer ID` STRING COLLATE UTF8_BINARY,
--   `Customer Name` STRING COLLATE UTF8_BINARY,
--   Segment STRING COLLATE UTF8_BINARY,
--   Country STRING COLLATE UTF8_BINARY,
--   City STRING COLLATE UTF8_BINARY,
--   State STRING COLLATE UTF8_BINARY,
--   `Postal Code` BIGINT,
--   Region STRING COLLATE UTF8_BINARY,
--   `Product ID` STRING COLLATE UTF8_BINARY,
--   Category STRING COLLATE UTF8_BINARY,
--   `Sub-Category` STRING COLLATE UTF8_BINARY,
--   `Product Name` STRING COLLATE UTF8_BINARY,
--   Sales DOUBLE,
--   Quantity BIGINT,
--   Discount DOUBLE,
--   Profit DOUBLE,
--   CONSTRAINT `superstore_pk` PRIMARY KEY (`Row ID`))
-- USING delta
-- COMMENT 'Created by the file upload UI'
-- TBLPROPERTIES (
--   'delta.checkpoint.writeStatsAsJson' = 'false',
--   'delta.checkpoint.writeStatsAsStruct' = 'true',
--   'delta.columnMapping.mode' = 'name',
--   'delta.enableDeletionVectors' = 'true',
--   'delta.feature.appendOnly' = 'supported',
--   'delta.feature.changeDataFeed' = 'supported',
--   'delta.feature.checkConstraints' = 'supported',
--   'delta.feature.columnMapping' = 'supported',
--   'delta.feature.deletionVectors' = 'supported',
--   'delta.feature.generatedColumns' = 'supported',
--   'delta.feature.invariants' = 'supported',
--   'delta.minReaderVersion' = '3',
--   'delta.minWriterVersion' = '7',
--   'delta.parquet.compression.codec' = 'zstd')
-- </td></tr></tbody></table></div>

-- %% [markdown]
-- **Note:** In SQL, backticks (`) are used for column/table names, while single quotes (') are used for string literals.

-- %% [markdown]
-- ## 2. Data Quality

-- %%
SELECT COUNT(*)
FROM superstore
WHERE Sales IS NULL;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>

-- %% [markdown]
-- ### Challenge 1
-- Find all Technology products sold in the West region.
--
-- ### Challenge 2
-- Find orders where sales are high but profit is negative. Why does this happen?
--
-- ### Challenge 3
-- Find customers from a specific state who purchased Furniture.
--
-- ### Challenge 4
-- Find products that received discounts above a chosen percentage.
--
-- ### Challenge 5
-- Find all orders placed during a holiday season (choose your own date range).

-- %% [markdown]
-- ## 3. Data Analysis Challenges

-- %%
select distinct `Product Name` from superstore 
where Region= 'West' and Category='Technology';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Product Name</th></tr></thead><tbody><tr><td>Mitel 5320 IP Phone VoIP phone</td></tr><tr><td>Konftel 250 Conference�phone�- Charcoal black</td></tr><tr><td>Cisco SPA 501G IP Phone</td></tr><tr><td>Imation�8GB Mini TravelDrive USB 2.0�Flash Drive</td></tr><tr><td>GE 30524EE4</td></tr><tr><td>Plantronics HL10 Handset Lifter</td></tr><tr><td>Panasonic Kx-TS550</td></tr><tr><td>Imation�8gb Micro Traveldrive Usb 2.0�Flash Drive</td></tr><tr><td>LF Elite 3D Dazzle Designer Hard Case Cover, Lf Stylus Pen and Wiper For Apple Iphone 5c Mini Lite</td></tr><tr><td>AT&T CL83451 4-Handset Telephone</td></tr><tr><td>Verbatim 25 GB 6x Blu-ray Single Layer Recordable Disc, 3/Pack</td></tr><tr><td>netTALK DUO VoIP Telephone Service</td></tr><tr><td>Logitech�LS21 Speaker System - PC Multimedia - 2.1-CH - Wired</td></tr><tr><td>SanDisk Ultra 64 GB MicroSDHC Class 10 Memory Card</td></tr><tr><td>Logitech K350 2.4Ghz Wireless Keyboard</td></tr><tr><td>Memorex Mini Travel Drive 8 GB USB 2.0 Flash Drive</td